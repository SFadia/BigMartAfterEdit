# %% [markdown]
# # Big Mart for Grocery Shopping
# ## by Fadia Saleh

# %% [markdown]
# ## Investigation Overview
#
# > In this investigation I  wanted to know what is the most factors that affect the price, after the bivaruite visiualization i found out that the main focus should be on (Item_Type,Item_Fat_Content,Item_MRP) coloumns which represents Item_Type : products,
# Item_Fat_Content: fats in each product type, Item_MRP: maximum retail price
#
# ## Dataset Overview
#
# > Data contains maximum retail price of different products types with different distrubution between low fats and regular fat content from Big Mart grocery stores

# %%
# import all packages and set plots to be embedded inline
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as sns
# %matplotlib inline
import matplotlib as matplotlib
import warnings
warnings.filterwarnings("ignore")

# %%
# load in the dataset into a pandas dataframe
Big_Mart_2 = pd.read_csv(r'C:\Users\FADIA\FWD 3rd project\Big_Mart_after_cleaning.csv')
Big_Mart_2.head()
# Out:
#   item_identifier  weight fat_content  visibility              item_type  \
# 0           fdw58  20.750     low fat    0.007565            snack foods
# 1           fdh56   9.800     regular    0.063817  fruits and vegetables
# 2           fdl48  19.350     regular    0.082602           baking goods
# 3           fdu11   4.785     low fat    0.092738                 breads
# 4           drl59  16.750     low fat    0.021206            hard drinks
#
#    max_retail_price outlet_identifier  outlet_establishment_year outlet_size  \
# 0          107.8622            out049                       1999      medium
# 1          117.1492            out046                       1997       small
# 2           50.1034            out018                       2009      medium
# 3          122.3098            out049                       1999      medium
# 4           52.0298            out013                       1987        high
#
#   outlet_location_type outlet_type
# ...

# %% [markdown]
# > Note that the above cells have been set as "Skip"-type slides. That means
# that when the notebook is rendered as http slides, those cells won't show up.

# %% [markdown]
# ## Pricing Based on the Products Type
#
# > In here we can see that the pricing is affected based on the product type not the availability of the product in the store

# %%
#point plot used to describe the expenseive products 
color_base=sns.color_palette()[0]
sns.pointplot(data=Big_Mart_2,y='max_retail_price',x='item_type', color=color_base,dodge=True);
plt.xticks(rotation=90);
#color_base=sns.color_palette()[0]
#sns.pointplot(data=Big_Mart_2,y='max_retail_price',x='item_type', color=color_base,linestyles=" ",dodge=True);
#plt.xticks(rotation=90);
plt.title('Pricing Based on the Products Type', fontsize=20);
plt.xlabel('Items');
plt.ylabel('Pricing');

# %% [markdown]
# ## Effect of Fat Content products on The Price
#
# > In here we see that the low fat products is more expensive than the regular fat products so fat content affect the price

# %%
#chart to show the relation between fat content products and its pricing 
color_base=sns.color_palette()[0]
sns.pointplot(data=Big_Mart_2,y='max_retail_price',x='fat_content', color=color_base,linestyles=" ",dodge=True);
plt.title('Pricing vs Fat Content Products', fontsize=20);
plt.xlabel('Fat content');
plt.ylabel('Pricing');

# %% [markdown]
# ## Effect of Both Fat Content Products Factor and Product Type Factor on The Price
#
# >In here we see that no matter what is the low fat product the price will be higher than the regular fat products

# %%
g = sns.FacetGrid(data = Big_Mart_2, col = 'item_type', col_wrap=6, sharey=False,margin_titles=True)
g.map(plt.scatter,'fat_content','max_retail_price');

# %% [markdown]
# > Once you're ready to finish your presentation, check your output by using
# nbconvert to export the notebook and set up a server for the slides. From the
# terminal or command line, use the following expression:
# > > `jupyter nbconvert <file_name>.ipynb --to slides --post serve --template output_toggle`
#
# > This should open a tab in your web browser where you can scroll through your
# presentation. Sub-slides can be accessed by pressing 'down' when viewing its parent
# slide. Make sure you remove all of the quote-formatted guide notes like this one
# before you finish your presentation!

# %%
# !jupyter nbconvert  BigMart_Grocery_Shopping.ipynb --to slides --no-prompt --no-input
# Out:
# [NbConvertApp] Converting notebook BigMart_Grocery_Shopping.ipynb to slides
# [NbConvertApp] Writing 692192 bytes to BigMart_Grocery_Shopping.slides.html
